# %% [markdown]
# <a href="https://colab.research.google.com/github/Gema-Villanueva/ComidasInternacionales/blob/main/Men%C3%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import random

def get_meal_suggestion():
    current_hour = datetime.datetime.now().hour

    full_menu_options = {
        "Desayuno": {
            "Primer Plato": [
                "Avena con frutas y frutos secos (Global - Vegano, Celiaco)",
                "Yogur griego con miel y nueces (Global)"
            ],
            "Segundo Plato": [
                "Tortilla de patatas (España)",
                "Pancakes con jarabe de arce y tocino (Estados Unidos)",
                "Tacos de nopales con frijoles (México - Vegano, Celiaco)"
            ],
            "Postre": [
                "Fruta fresca de temporada (Global - Vegano, Celiaco)",
                "Macedonia de frutas tropicales (Global - Vegano, Celiaco)"
            ],
            "Bebida": [
                "Café",
                "Té verde",
                "Zumo de naranja natural"
            ]
        },
        "Comida": {
            "Primer Plato": [
                "Crema de calabaza (Global - Vegano, Celiaco)",
                "Ensalada mixta con aderezo de vinagreta (Global - Vegano, Celiaco)",
                "Sopa de tortilla (México - Celiaco)"
            ],
            "Segundo Plato": [
                "Lasaña boloñesa (Italia)",
                "Curry de lentejas (Dal Makhani) con arroz (India - Vegano, Celiaco)",
                "Pozole rojo (México - Celiaco)",
                "Risotto de champiñones (Italia - Celiaco)"
            ],
            "Postre": [
                "Tiramisú (Italia)",
                "Fruta fresca (Global - Vegano, Celiaco)",
                "Flan casero (España - Celiaco)"
            ],
            "Bebida": [
                "Agua mineral",
                "Refresco de cola",
                "Vino tinto (España)"
            ]
        },
        "Merienda": {
            "Primer Plato": [
                "Brochetas de fruta (Global - Vegano, Celiaco)",
                "Mini sándwiches variados (Global)"
            ],
            "Segundo Plato": [
                "Crêpes de chocolate y plátano (Francia)",
                "Edamame (Japón - Vegano, Celiaco)",
                "Churros con chocolate (España)"
            ],
            "Postre": [
                "Magdalenas caseras (Global)",
                "Galletas de avena (Global - Vegano, Celiaco)"
            ],
            "Bebida": [
                "Café con leche",
                "Té de hierbas",
                "Batido de frutas (Global - Vegano)"
            ]
        },
        "Cena": {
            "Primer Plato": [
                "Ensalada César (Global)",
                "Sopa de miso (Japón - Vegano, Celiaco)",
                "Crema de espárragos (Global - Vegano, Celiaco)"
            ],
            "Segundo Plato": [
                "Pad Thai con gambas (Tailandia - Celiaco)",
                "Pasta con pesto de albahaca (Italia - Vegano)",
                "Asado de tira (Argentina)",
                "Salmón al horno con patatas (Noruega - Celiaco)"
            ],
            "Postre": [
                "Brownie de chocolate con helado (Global)",
                "Panna Cotta (Italia - Celiaco)",
                "Mousse de aguacate y cacao (Global - Vegano, Celiaco)"
            ],
            "Bebida": [
                "Agua con gas",
                "Cerveza artesanal",
                "Té Rooibos"
            ]
        }
    }

    if 6 <= current_hour < 11:  # 6 AM to 10:59 AM
        meal_time = "Desayuno"
    elif 11 <= current_hour < 16:  # 11 AM to 3:59 PM
        meal_time = "Comida"
    elif 16 <= current_hour < 19:  # 4 PM to 6:59 PM
        meal_time = "Merienda"
    else:  # 7 PM to 5:59 AM
        meal_time = "Cena"

    print(f"¡Es hora de {meal_time}! Aquí tienes las opciones de menú:")

    selected_menu = {}
    for course, options in full_menu_options[meal_time].items():
        print(f"\n--- {course} ---")
        for i, option in enumerate(options):
            print(f"{i + 1}. {option}")

        while True:
            try:
                choice = int(input(f"Elige una opción para {course} (número): "))
                if 1 <= choice <= len(options):
                    selected_menu[course] = options[choice - 1]
                    break
                else:
                    print("Opción inválida. Por favor, elige un número de la lista.")
            except ValueError:
                print("Entrada inválida. Por favor, ingresa un número.")

    print(f"\n¡Has elegido tu menú para {meal_time}!")
    for course, selection in selected_menu.items():
        print(f"{course}: {selection}")

# Call the function to get a meal suggestion
get_meal_suggestion()
# Out:
# ¡Es hora de Comida! Aquí tienes las opciones de menú:
#
# --- Primer Plato ---
# 1. Crema de calabaza (Global - Vegano, Celiaco)
# 2. Ensalada mixta con aderezo de vinagreta (Global - Vegano, Celiaco)
# 3. Sopa de tortilla (México - Celiaco)
# Elige una opción para Primer Plato (número): 2
#
# --- Segundo Plato ---
# 1. Lasaña boloñesa (Italia)
# 2. Curry de lentejas (Dal Makhani) con arroz (India - Vegano, Celiaco)
# 3. Pozole rojo (México - Celiaco)
# 4. Risotto de champiñones (Italia - Celiaco)
# Elige una opción para Segundo Plato (número): 3
#
# --- Postre ---
# 1. Tiramisú (Italia)
# 2. Fruta fresca (Global - Vegano, Celiaco)
# 3. Flan casero (España - Celiaco)
# Elige una opción para Postre (número): 2
#
# --- Bebida ---
# 1. Agua mineral
# 2. Refresco de cola
# 3. Vino tinto (España)
# Elige una opción para Bebida (número): 2
#
# ¡Has elegido tu menú para Comida!
# Primer Plato: Ensalada mixta con aderezo de vinagreta (Global - Vegano, Celiaco)
# ...
